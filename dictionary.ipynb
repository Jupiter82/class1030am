# %%
# d = {<key>:<value>,<key>:<value>,<key>:<value>}

# %%
d = {"A":"Apple","B":"Ball"}
d["B"]
# Out:
# 'Ball'

# %%
#nutable
#indexed
#ordered
#Duplicate

# %%
d={}
d['A'] = "Appple"
d["B"] = "Ball"
d
# Out:
# {'A': 'Appple', 'B': 'Ball'}

# %%
d["A"] = "Ant"
d
# Out:
# {'A': 'Ant', 'B': 'Ball'}

# %%
d={}
d[0] = "Appple"
d[1] = "Ball"
d
# Out:
# {0: 'Appple', 1: 'Ball'}

# %%
d[1]
# Out:
# 'Ball'

# %%
info = {}
for i in range(2):
    name = input("Enter the name =")
    phone = int(input("Enter the phone ="))
    info[name] = phone
print(info)
# Out:
# Enter the name =jupiter
# Enter the phone =090909
# Enter the name =ram
# Enter the phone =090909
# {'jupiter': 90909, 'ram': 90909}

# %%
a = {"a":"Apple","c":"Cat"}
b = {"b":"Ball"}
a.update(b)
print(a)
# Out:
# {'a': 'Apple', 'c': 'Cat', 'b': 'Ball'}

# %%
for i in a:
    print(i)
# Out:
# a
# c
# b

# %%
for i in a.values():
    print(i)
# Out:
# Apple
# Cat
# Ball

# %%
for i in a.items():
    print(i)
# Out:
# ('a', 'Apple')
# ('c', 'Cat')
# ('b', 'Ball')

# %%
info = {}
for i in range(2):
    name = input("Enter the name =")
    ncell_phone = int(input("Enter the ncell phone ="))
    ntc_phone = int(input("Enter the ntc phone ="))
    info[name] = [ncell_phone,ntc_phone]
print(info)
# Out:
# Enter the name =jupiter
# Enter the ncell phone =989890809
# Enter the ntc phone =98498948094
# Enter the name =ram
# Enter the ncell phone =98980989
# Enter the ntc phone =98498980948
# {'jupiter': [989890809, 98498948094], 'ram': [98980989, 98498980948]}

# %%
name = input("Enter the name = ")
print(info[name])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-5e939b9c686b> in <module>
# ----> 1 name = input("Enter the name = ")
#       2 print(info[name])
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
d = {'jupiter': [989890809, 98498948094], 'ram': [98980989, 98498980948]}
del d["jupiter"][1]
d

# %%
{'jupiter': [989890809, 98498948094], 'ram': [98980989, 98498980948]}
d["jupiter"].append(445655656)
d
# Out:
# {'jupiter': [989890809, 445655656, 445655656], 'ram': [98980989, 98498980948]}

# %%
b = {}
a ={"a":"Apple","b":"Ball"}
for i in a.items():
    key = i[0].upper()
    value = i[1]
    b[key] = value
b
# Out:
# {'A': 'Apple', 'B': 'Ball'}

# %%
b={}
a ={"a":"Apple","b":"Ball"}

a.pop("a")
a
# Out:
# {'b': 'Ball'}

# %%
b={"A":"Apple"}
b.update(a)
b
# Out:
# {'A': 'Apple', 'b': 'Ball'}

# %%
b = {}
a ={"a":"Apple","b":"Ball"}
for i in a.items():
    key = i[0]
    if key == "a":
        value = i[1]
    b[key] = value
b
# Out:
# {'a': 'Apple', 'b': 'Apple'}

# %%
#a = [{""}] #dictionary inside list important

# %%
#dictionary inside list 
a = [{"Ram":989887897879},{"shyam":909098098}]
a
# Out:
# [{'Ram': 989887897879}, {'shyam': 909098098}]

# %%
a[0]
# Out:
# {'Ram': 989887897879}

# %%
a.append({"Hari":989089809890})
a
# Out:
# [{'Ram': 989887897879}, {'shyam': 909098098}, {'Hari': 989089809890}]

# %%
z = []
n = int(input("enter the value of n = "))
for i in range(n):
    name = input("Enter the name =")
    phone = int(input("Enter the name ="))
    d = {name:phone}
    z.append(d)
print(z)
# Out:
# enter the value of n = 2
# Enter the name =jupiter
# Enter the name =98989898
# Enter the name =ram
# Enter the name =989809
# [{'jupiter': 98989898}, {'ram': 989809}]

# %%
# dictionary inside dictionary
a = {"Ram":{"NTC":9843435743,"NCELL":9834345345},"Shyam":{"NTC":9843435743,"NCELL":9834345345}}
print(a)
# Out:
# {'Ram': {'NTC': 9843435743, 'NCELL': 9834345345}, 'Shyam': {'NTC': 9843435743, 'NCELL': 9834345345}}

# %%
for i in a.values():
    print(i)
# Out:
# {'NTC': 9843435743, 'NCELL': 9834345345}
# {'NTC': 9843435743, 'NCELL': 9834345345}

# %%
for i in a.items():
    print(i)
# Out:
# ('Ram', {'NTC': 9843435743, 'NCELL': 9834345345})
# ('Shyam', {'NTC': 9843435743, 'NCELL': 9834345345})

# %%
a["Hari"] = {"NTC":989767887,"NCELL":989709809}
a
# Out:
# {'Ram': {'NTC': 9843435743, 'NCELL': 9834345345},
#  'Shyam': {'NTC': 9843435743, 'NCELL': 9834345345},
#  'Hari': {'NTC': 989767887, 'NCELL': 989709809}}

# %%
a["Hari"]["NTC"] = 9000000000
a
# Out:
# {'Ram': {'NTC': 9843435743, 'NCELL': 9834345345},
#  'Shyam': {'NTC': 9843435743, 'NCELL': 9834345345},
#  'Hari': {'NTC': 9000000000, 'NCELL': 989709809}}

# %%
a = {("Apple","Ant"):"A"}
a
# Out:
# {('Apple', 'Ant'): 'A'}
